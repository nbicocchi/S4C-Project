# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# --- 1. Leggi il dataset ---
df = pd.read_excel("marzo2022_settembre2025.xlsx", sheet_name="dati pedoni orari")

# Combina data + ora in datetime
df["datetime"] = pd.to_datetime(df["data"].astype(str) + " " + df["ora"].astype(str))

# Rimuovi colonne originali
df = df.drop(columns=["data", "ora"])

# --- 2. Seleziona telecamera ---
telecamera_scelta = "Arcoribellino"
df_cam = df[df["telecamera"] == telecamera_scelta].copy()
df_cam = df_cam.reset_index(drop=True)

# --- 3. Crea colonne utili ---
df_cam["giorno"] = df_cam["datetime"].dt.date
df_cam["ora"] = df_cam["datetime"].dt.hour + df_cam["datetime"].dt.minute / 60

df_cam
# Out:
#           telecamera  entra  uscita            datetime      giorno        ora
# 0      Arcoribellino      1       2 2022-03-01 00:00:00  2022-03-01   0.000000
# 1      Arcoribellino      1       0 2022-03-01 01:00:00  2022-03-01   1.000000
# 2      Arcoribellino      0       0 2022-03-01 02:00:00  2022-03-01   2.000000
# 3      Arcoribellino      0       0 2022-03-01 03:00:00  2022-03-01   3.000000
# 4      Arcoribellino      0       0 2022-03-01 04:00:00  2022-03-01   4.000000
# ...              ...    ...     ...                 ...         ...        ...
# 25884  Arcoribellino     17      14 2025-09-30 20:00:00  2025-09-30  20.000000
# 25885  Arcoribellino     18       8 2025-09-30 21:00:00  2025-09-30  21.000000
# 25886  Arcoribellino      5      12 2025-09-30 22:00:00  2025-09-30  22.000000
# 25887  Arcoribellino      3      11 2025-09-30 23:00:00  2025-09-30  23.000000
# 25888  Arcoribellino      7       3 2025-09-30 23:59:59  2025-09-30  23.983333
#
# ...

# %%
import matplotlib.pyplot as plt

# Estrai giorno della settimana e ora
df_cam["giorno_settimana"] = df_cam["datetime"].dt.dayofweek  # 0=lunedì, 6=domenica
df_cam["ora"] = df_cam["datetime"].dt.hour

# Raggruppa e calcola la media per 'entra'
weekly_avg_entra = df_cam.groupby(["giorno_settimana", "ora"])["entra"].mean().reset_index()
# Raggruppa e calcola la media per 'uscita'
weekly_avg_uscita = df_cam.groupby(["giorno_settimana", "ora"])["uscita"].mean().reset_index()

# Definisci i nomi dei giorni
giorni = ["Lunedì", "Martedì", "Mercoledì", "Giovedì", "Venerdì", "Sabato", "Domenica"]

# ===== Grafico ENTRA =====
plt.figure(figsize=(12, 6))
for i in range(7):
    subset = weekly_avg_entra[weekly_avg_entra["giorno_settimana"] == i]
    plt.plot(subset["ora"], subset["entra"], marker='o', label=giorni[i])

plt.xlabel("Ora della giornata")
plt.ylabel("Media entrate")
plt.title(f"Andamento medio delle entrate per giorno della settimana - Telecamera {telecamera_scelta}")
plt.xticks(range(0,25))
plt.grid(True)
plt.legend()
plt.show()

# ===== Grafico USCITA =====
plt.figure(figsize=(12, 6))
for i in range(7):
    subset = weekly_avg_uscita[weekly_avg_uscita["giorno_settimana"] == i]
    plt.plot(subset["ora"], subset["uscita"], marker='o', label=giorni[i])

plt.xlabel("Ora della giornata")
plt.ylabel("Media uscite")
plt.title(f"Andamento medio delle uscite per giorno della settimana - Telecamera {telecamera_scelta}")
plt.xticks(range(0,25))
plt.grid(True)
plt.legend()
plt.show()

# %%
# Aggregazione per giorno e telecamera
daily_totals = df_cam.groupby(["telecamera", "giorno"], as_index=False).agg({
    "entra": "sum",
    "uscita": "sum"
})

# Assicurati che 'giorno' sia in formato datetime
daily_totals["giorno"] = pd.to_datetime(daily_totals["giorno"])

# Aggiungi il giorno della settimana (0=lunedì, 6=domenica)
daily_totals["giorno_settimana"] = daily_totals["giorno"].dt.weekday

daily_totals
# Out:
#          telecamera     giorno  entra  uscita  giorno_settimana
# 0     Arcoribellino 2022-03-01    286     274                 1
# 1     Arcoribellino 2022-03-02    291     309                 2
# 2     Arcoribellino 2022-03-03    263     296                 3
# 3     Arcoribellino 2022-03-04    292     283                 4
# 4     Arcoribellino 2022-03-05    763     769                 5
# ...             ...        ...    ...     ...               ...
# 1120  Arcoribellino 2025-09-26    375     399                 4
# 1121  Arcoribellino 2025-09-27    708     686                 5
# 1122  Arcoribellino 2025-09-28    973    1013                 6
# 1123  Arcoribellino 2025-09-29    298     327                 0
# 1124  Arcoribellino 2025-09-30    294     327                 1
#
# [1125 rows x 5 columns]

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Assicurati che 'giorno' sia datetime
daily_totals["giorno"] = pd.to_datetime(daily_totals["giorno"])

# Estrai il mese
daily_totals["mese"] = daily_totals["giorno"].dt.month

# Mappa numeri giorno della settimana a nomi
giorni_nome = {0: "Monday", 1: "Tuesday", 2: "Wednesday", 3: "Thursday",
               4: "Friday", 5: "Saturday", 6: "Sunday"}
daily_totals["giorno_settimana_nome"] = daily_totals["giorno_settimana"].map(giorni_nome)

# Pivot table: media entrate per giorno della settimana e mese
pivot = daily_totals.pivot_table(
    index="giorno_settimana_nome",
    columns="mese",
    values="entra",
    aggfunc="mean"
)

# Ordinamento giorni della settimana
pivot = pivot.reindex(["Monday","Tuesday","Wednesday","Thursday","Friday","Saturday","Sunday"])

# Heatmap
plt.figure(figsize=(12,6))
sns.heatmap(pivot, annot=True, fmt=".0f", cmap="YlGnBu")
plt.xlabel("Month")
plt.ylabel("Day of the Week")
plt.title("Average Entries by Day of the Week and Month")
plt.show()

# %%
import numpy as np
import pandas as pd

# Assicurati che 'giorno' sia datetime
daily_totals["giorno"] = pd.to_datetime(daily_totals["giorno"])

# Calcola trimestre
daily_totals["trimestre"] = daily_totals["giorno"].dt.to_period("Q")

# Calcola media e deviazione standard per giorno della settimana all'interno di ogni trimestre
stats_trimestre = daily_totals.groupby(["trimestre", "giorno_settimana"])["entra"].agg(["mean", "std"]).reset_index()
stats_trimestre = stats_trimestre.rename(columns={"mean": "media", "std": "devstd"})

# Unisci le statistiche al dataframe originale
daily_totals = daily_totals.merge(stats_trimestre, on=["trimestre", "giorno_settimana"], how="left")

# Calcola numero di deviazioni standard sopra la media
dev_std = (daily_totals["entra"] - daily_totals["media"]) / daily_totals["devstd"]

# Livello anomalia: tutte le dev std < 0 → 0, max 3
daily_totals["anomalia"] = np.floor(dev_std).clip(lower=0, upper=3).astype(int)

# Rimuovi colonne temporanee
daily_totals = daily_totals.drop(columns=["media", "devstd"])

# Salva giorno e livello anomalia
daily_totals[["giorno", "anomalia"]].to_csv("eventi_devstd_trimestre.csv", index=False)

daily_totals
# Out:
#          telecamera     giorno  entra  uscita  giorno_settimana  mese  \
# 0     Arcoribellino 2022-03-01    286     274                 1     3
# 1     Arcoribellino 2022-03-02    291     309                 2     3
# 2     Arcoribellino 2022-03-03    263     296                 3     3
# 3     Arcoribellino 2022-03-04    292     283                 4     3
# 4     Arcoribellino 2022-03-05    763     769                 5     3
# ...             ...        ...    ...     ...               ...   ...
# 1120  Arcoribellino 2025-09-26    375     399                 4     9
# 1121  Arcoribellino 2025-09-27    708     686                 5     9
# 1122  Arcoribellino 2025-09-28    973    1013                 6     9
# 1123  Arcoribellino 2025-09-29    298     327                 0     9
# 1124  Arcoribellino 2025-09-30    294     327                 1     9
#
#      giorno_settimana_nome trimestre  anomalia
# 0                  Tuesday    2022Q1         0
# ...

# %%
# Conteggio dei giorni per livello di anomalia
conteggio = daily_totals["anomalia"].value_counts().sort_index()
print(conteggio)
# Out:
# anomalia
# 0    981
# 1     82
# 2     46
# 3     16
# Name: count, dtype: int64

# %%
# Filtra i giorni del 2025 con anomalia > 0
anomali = daily_totals[(daily_totals["anomalia"] > 0)]

# Mostra le righe
anomali
# Out:
#          telecamera     giorno  entra  uscita  giorno_settimana  mese  \
# 1     Arcoribellino 2022-03-02    291     309                 2     3
# 23    Arcoribellino 2022-03-24    331     371                 3     3
# 24    Arcoribellino 2022-03-25    366     399                 4     3
# 26    Arcoribellino 2022-03-27   1566    1790                 6     3
# 27    Arcoribellino 2022-03-28    275     300                 0     3
# ...             ...        ...    ...     ...               ...   ...
# 1101  Arcoribellino 2025-09-07   2028    2125                 6     9
# 1102  Arcoribellino 2025-09-08    868     809                 0     9
# 1110  Arcoribellino 2025-09-16    422     447                 1     9
# 1111  Arcoribellino 2025-09-17    410     464                 2     9
# 1112  Arcoribellino 2025-09-18    526     536                 3     9
#
#      giorno_settimana_nome trimestre  anomalia
# 1                Wednesday    2022Q1         1
# ...

# %%
import matplotlib.pyplot as plt
import matplotlib.cm as cm
import matplotlib.colors as mcolors

fig, ax = plt.subplots(figsize=(15,6))

# Define palette for days of the week
days = ["Monday", "Tuesday", "Wednesday", "Thursday", "Friday", "Saturday", "Sunday"]
palette = cm.tab10  # 10 distinct colors

# Normalize anomaly level for point size
anomaly_norm = mcolors.Normalize(vmin=daily_totals["anomalia"].min(), vmax=daily_totals["anomalia"].max())
sizes = 50 + 150 * anomaly_norm(daily_totals["anomalia"])  # higher anomaly = bigger point

# Scatter plot
for i, day_name in enumerate(days):
    subset = daily_totals[daily_totals["giorno_settimana"] == i]
    ax.scatter(
        subset["giorno"],
        subset["entra"],
        c=[palette(i)]*len(subset),  # color by day of the week
        s=50 + 150 * anomaly_norm(subset["anomalia"]),  # size based on anomaly
        alpha=0.7,
        label=day_name
    )

ax.set_xlabel("Date")
ax.set_ylabel("People")
ax.set_title(f"Daily Entries - Color=Day, Size=Anomaly - Camera {telecamera_scelta}")
ax.tick_params(axis='x', rotation=45)
ax.grid(True)
ax.legend(title="Day of the Week")
plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt
import pandas as pd

# Assicurati che 'giorno' sia datetime
daily_totals["giorno"] = pd.to_datetime(daily_totals["giorno"])

# Seleziona solo l'anno 2025 e i mesi indicati
selected_months = [3, 5, 8, 9]  # marzo, maggio, agosto, settembre
filtered = daily_totals[
    (daily_totals["giorno"].dt.year == 2025) &
    (daily_totals["giorno"].dt.month.isin(selected_months))
].copy()

# Grafico principale
plt.figure(figsize=(15,6))
plt.plot(filtered["giorno"], filtered["entra"], marker='o', label="Ingressi")
plt.plot(filtered["giorno"], filtered["uscita"], marker='o', label="Uscite")

# Evidenzia anomalie in base al livello (>0)
if "anomalia" in filtered.columns:
    anomali = filtered[filtered["anomalia"] > 0]
    # Marker proporzionale al livello di anomalia
    plt.scatter(
        anomali["giorno"], anomali["entra"],
        s=50 + 20*anomali["anomalia"],  # dimensione marker proporzionale
        color="red", label="Anomalie", zorder=5
    )
    plt.scatter(
        anomali["giorno"], anomali["uscita"],
        s=50 + 20*anomali["anomalia"],
        color="red", zorder=5
    )

# Linee verticali sottili per le domeniche
sundays = filtered[filtered["giorno"].dt.weekday == 6]["giorno"]
for sunday in sundays:
    plt.axvline(sunday, color='gray', linestyle='--', linewidth=0.5)

plt.title(f"Ingressi e Uscite giornalieri - Telecamera {telecamera_scelta} - Mesi selezionati 2025")
plt.xlabel("Data")
plt.ylabel("Persone")
plt.xticks(rotation=45)
plt.grid(True)
plt.legend()
plt.tight_layout()
plt.show()

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

from sklearn.ensemble import GradientBoostingRegressor
from sklearn.model_selection import TimeSeriesSplit, RandomizedSearchCV
from sklearn.metrics import mean_squared_error, mean_absolute_error

# ======================================================
# 1️⃣ PREPARAZIONE DATI
# ======================================================

# Assicurati che 'giorno' sia datetime
daily_totals["giorno"] = pd.to_datetime(daily_totals["giorno"])

# Ordina temporalmente
daily_totals = daily_totals.sort_values("giorno").reset_index(drop=True)

# Feature temporali
daily_totals["giorno_settimana"] = daily_totals["giorno"].dt.weekday
daily_totals["mese"] = daily_totals["giorno"].dt.month
daily_totals["giorno_mese"] = daily_totals["giorno"].dt.day


# Rimuove righe con NaN dovute ai lag
daily_totals = daily_totals.dropna().reset_index(drop=True)

# Feature e target
feature_cols = [
    "giorno_settimana",
    "mese",
    "giorno_mese",
    "anomalia",
]

X = daily_totals[feature_cols]
y = daily_totals["entra"]

# ======================================================
# 2️⃣ CROSS-VALIDATION TEMPORALE
# ======================================================

tscv = TimeSeriesSplit(n_splits=5)

# ======================================================
# 3️⃣ SPAZIO IPERPARAMETRI
# ======================================================

param_distributions = {
    "n_estimators": [100, 200, 300, 500],
    "learning_rate": [0.01, 0.05, 0.1, 0.2],
    "max_depth": [2, 3, 4, 5],
    "min_samples_split": [2, 5, 10],
    "min_samples_leaf": [1, 3, 5],
    "subsample": [0.6, 0.8, 1.0]
}

# ======================================================
# 4️⃣ RANDOMIZED SEARCH
# ======================================================

gbr = GradientBoostingRegressor(random_state=42)

random_search = RandomizedSearchCV(
    estimator=gbr,
    param_distributions=param_distributions,
    n_iter=40,
    cv=tscv,
    scoring="neg_root_mean_squared_error",
    n_jobs=-1,
    random_state=42,
    verbose=1
)

random_search.fit(X, y)

best_model = random_search.best_estimator_

print("\nMigliori iperparametri:")
print(random_search.best_params_)

# ======================================================
# 5️⃣ TRAIN / TEST SPLIT FINALE (ULTIMO 10%)
# ======================================================

split_idx = int(len(X) * 0.9)

X_train, X_test = X.iloc[:split_idx], X.iloc[split_idx:]
y_train, y_test = y.iloc[:split_idx], y.iloc[split_idx:]

best_model.fit(X_train, y_train)
y_pred = best_model.predict(X_test)

# ======================================================
# 6️⃣ METRICHE
# ======================================================

rmse = np.sqrt(mean_squared_error(y_test, y_pred))
mae = mean_absolute_error(y_test, y_pred)
mape = np.mean(np.abs((y_test - y_pred) / y_test)) * 100

print(f"\nRMSE: {rmse:.2f}")
print(f"MAE: {mae:.2f}")
print(f"MAPE: {mape:.2f}%")

# ======================================================
# 7️⃣ VISUALIZZAZIONE
# ======================================================

plt.figure(figsize=(12, 6))
plt.plot(y_test.values, label="Valore reale", marker="o")
plt.plot(y_pred, label="Predetto", marker="x")
plt.xlabel("Giorni test")
plt.ylabel("Entrate totali giornaliere")
plt.title(f"Predizione Entrate giornaliere - Telecamera {telecamera_scelta}")
plt.legend()
plt.grid(True)
plt.show()
# Out:
# Fitting 5 folds for each of 40 candidates, totalling 200 fits
#
# Migliori iperparametri:
# {'subsample': 1.0, 'n_estimators': 100, 'min_samples_split': 10, 'min_samples_leaf': 3, 'max_depth': 2, 'learning_rate': 0.05}
#
# RMSE: 136.15
# MAE: 91.44
# MAPE: 21.24%

# %%
import joblib

# Salva il modello in un file .pkl
filename = "pedestrians_model.pkl"
joblib.dump(best_model, filename)

print(f"Modello salvato in {filename}")
# Out:
# Modello salvato in pedestrians_model.pkl

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

from sklearn.ensemble import GradientBoostingRegressor
from sklearn.model_selection import TimeSeriesSplit, RandomizedSearchCV
from sklearn.metrics import mean_squared_error, mean_absolute_error
from sklearn.preprocessing import OneHotEncoder

# ======================================================
# 1️⃣ PREPARAZIONE DATI
# ======================================================

# Assicurati che 'giorno' sia datetime
daily_totals["giorno"] = pd.to_datetime(daily_totals["giorno"])

# Ordina temporalmente
daily_totals = daily_totals.sort_values("giorno").reset_index(drop=True)

# Feature temporali
daily_totals["giorno_settimana"] = daily_totals["giorno"].dt.weekday
daily_totals["mese"] = daily_totals["giorno"].dt.month
daily_totals["giorno_mese"] = daily_totals["giorno"].dt.day

# Rolling features
daily_totals["entra_roll7_mean"] = daily_totals["entra"].rolling(window=7, min_periods=1).mean()
daily_totals["entra_roll7_std"] = daily_totals["entra"].rolling(window=7, min_periods=1).std().fillna(0)

# One-hot encoding delle anomalie
encoder = OneHotEncoder(sparse_output=False, dtype=int)
anomalia_ohe = encoder.fit_transform(daily_totals[["anomalia"]])
anomalia_df = pd.DataFrame(anomalia_ohe, columns=[f"anomalia_{int(c)}" for c in encoder.categories_[0]])
daily_totals = pd.concat([daily_totals.reset_index(drop=True), anomalia_df], axis=1)

# Rimuove righe con NaN dovute ai lag o rolling
daily_totals = daily_totals.dropna().reset_index(drop=True)

# Feature e target
feature_cols = [
    "giorno_settimana",
    "mese",
    "giorno_mese",
    "entra_roll7_mean",
    "entra_roll7_std"
] + list(anomalia_df.columns)

X = daily_totals[feature_cols]
y = daily_totals["entra"]

# ======================================================
# 2️⃣ CROSS-VALIDATION TEMPORALE
# ======================================================

tscv = TimeSeriesSplit(n_splits=5)

# ======================================================
# 3️⃣ SPAZIO IPERPARAMETRI ESPANSO
# ======================================================

param_distributions = {
    "n_estimators": [100, 200, 300, 500, 700, 1000],
    "learning_rate": [0.01, 0.02, 0.05, 0.1],
    "max_depth": [2, 3, 4, 5, 6],
    "min_samples_split": [2, 5, 10, 20],
    "min_samples_leaf": [1, 2, 3, 5],
    "subsample": [0.6, 0.8, 1.0],
    "max_features": [None, "sqrt", "log2"]
}

# ======================================================
# 4️⃣ RANDOMIZED SEARCH
# ======================================================

gbr = GradientBoostingRegressor(random_state=42)

random_search = RandomizedSearchCV(
    estimator=gbr,
    param_distributions=param_distributions,
    n_iter=50,
    cv=tscv,
    scoring="neg_root_mean_squared_error",
    n_jobs=-1,
    random_state=42,
    verbose=1
)

random_search.fit(X, y)

best_model = random_search.best_estimator_

print("\nMigliori iperparametri:")
print(random_search.best_params_)

# ======================================================
# 5️⃣ TRAIN / TEST SPLIT FINALE (ULTIMO 10%)
# ======================================================

split_idx = int(len(X) * 0.9)

X_train, X_test = X.iloc[:split_idx], X.iloc[split_idx:]
y_train, y_test = y.iloc[:split_idx], y.iloc[split_idx:]

best_model.fit(X_train, y_train)
y_pred = best_model.predict(X_test)

# ======================================================
# 6️⃣ METRICHE
# ======================================================

rmse = np.sqrt(mean_squared_error(y_test, y_pred))
mae = mean_absolute_error(y_test, y_pred)
mape = np.mean(np.abs((y_test - y_pred) / y_test)) * 100

print(f"\nRMSE: {rmse:.2f}")
print(f"MAE: {mae:.2f}")
print(f"MAPE: {mape:.2f}%")

# ======================================================
# 7️⃣ VISUALIZZAZIONE
# ======================================================

plt.figure(figsize=(12, 6))
plt.plot(y_test.values, label="Valore reale", marker="o")
plt.plot(y_pred, label="Predetto", marker="x")
plt.xlabel("Giorni test")
plt.ylabel("Entrate totali giornaliere")
plt.title(f"Predizione Entrate giornaliere - Telecamera {telecamera_scelta}")
plt.legend()
plt.grid(True)
plt.show()
# Out:
# Fitting 5 folds for each of 50 candidates, totalling 250 fits
#
# Migliori iperparametri:
# {'subsample': 0.8, 'n_estimators': 500, 'min_samples_split': 5, 'min_samples_leaf': 2, 'max_features': None, 'max_depth': 6, 'learning_rate': 0.01}
#
# RMSE: 84.18
# MAE: 59.47
# MAPE: 14.34%
