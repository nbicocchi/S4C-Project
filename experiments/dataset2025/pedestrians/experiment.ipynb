# %%
import pandas as pd

df = pd.read_excel("marzo2022_settembre2025.xlsx", sheet_name="dati pedoni orari")

# Assicurati che 'data' sia datetime
df['data'] = pd.to_datetime(df['data'])

# 1️⃣ Crea colonna 'day' per aggregazione giornaliera
df['day'] = df['data'].dt.date

# 2️⃣ Pivot per wide format: telecamera-entra, telecamera-uscita
df_wide = df.pivot_table(
    index='day',
    columns='telecamera',
    values=['entra','uscita'],
    aggfunc='sum'  # somma se ci sono più righe per lo stesso giorno
).reset_index()

# 3️⃣ Rimuovi multi-index sulle colonne e crea nomi tipo 'telecamera-entra'
df_wide.columns = [f"{col[1]}-{col[0]}" if col[1] else col[0] for col in df_wide.columns.values]

df_wide
# Out:
#              day  Arcoribellino-entra  Piazzarocca Ingresso-entra  \
# 0     2022-03-01                286.0                         NaN
# 1     2022-03-02                291.0                         NaN
# 2     2022-03-03                263.0                         NaN
# 3     2022-03-04                292.0                        92.0
# 4     2022-03-05                763.0                       709.0
# ...          ...                  ...                         ...
# 1121  2025-09-26                375.0                       230.0
# 1122  2025-09-27                708.0                       573.0
# 1123  2025-09-28                973.0                       752.0
# 1124  2025-09-29                298.0                       198.0
# 1125  2025-09-30                294.0                       206.0
#
#       Piazzarocca Uscita-entra  Arcoribellino-uscita  \
# 0                          NaN                 274.0
# 1                          NaN                 309.0
# 2                          NaN                 296.0
# 3                         51.0                 283.0
# 4                        667.0                 769.0
# ...                        ...                   ...
# 1121                       3.0                 399.0
# 1122                       2.0                 686.0
# 1123                       0.0                1013.0
# 1124                       2.0                 327.0
# 1125                       2.0                 327.0
#
#       Piazzarocca Ingresso-uscita  Piazzarocca Uscita-uscita
# 0                             NaN                        NaN
# 1                             NaN                        NaN
# 2                             NaN                        NaN
# 3                            64.0                       49.0
# 4                           756.0                      532.0
# ...                           ...                        ...
# 1121                          1.0                      246.0
# 1122                          8.0                      636.0
# 1123                          7.0                      884.0
# 1124                          2.0                      206.0
# 1125                          0.0                      215.0
#
# [1126 rows x 7 columns]

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

corr = df_wide.drop(columns=['day']).corr()
plt.figure(figsize=(12,10))
sns.heatmap(corr, annot=True, fmt=".2f", cmap='coolwarm', cbar=True)
plt.title('Correlazione tra telecamere (entra/uscita)')
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt

plt.figure(figsize=(15,6))

# Cicla su tutte le colonne e plottale
for col in df_wide.columns:
    if col == 'day':
        continue
    # Usa linea continua per 'entra' e tratteggiata per 'uscita'
    if 'entra' in col:
        plt.plot(df_wide['day'], df_wide[col], label=col)
    else:
        plt.plot(df_wide['day'], df_wide[col], linestyle='--', label=col)

plt.xlabel('Data')
plt.ylabel('Persone')
plt.title('Serie temporali giornaliere per tutte le telecamere (entra/uscita)')
plt.legend(fontsize=8, ncol=2)  # legend più compatta
plt.grid(True)
plt.tight_layout()
plt.show()

# %%
# Seleziona solo la colonna 'day' e quella che vuoi tenere
# Ad esempio 'Arcoribellino-entra'
df_simple = df_wide[['day', 'Arcoribellino-entra']].rename(columns={'Arcoribellino-entra':'telecamera'})

df_simple
# Out:
#              day  telecamera
# 0     2022-03-01       286.0
# 1     2022-03-02       291.0
# 2     2022-03-03       263.0
# 3     2022-03-04       292.0
# 4     2022-03-05       763.0
# ...          ...         ...
# 1121  2025-09-26       375.0
# 1122  2025-09-27       708.0
# 1123  2025-09-28       973.0
# 1124  2025-09-29       298.0
# 1125  2025-09-30       294.0
#
# [1126 rows x 2 columns]

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Assicurati che 'day' sia datetime
df_simple['day'] = pd.to_datetime(df_simple['day'])

# Estrai il mese
df_simple['mese'] = df_simple['day'].dt.month

# Estrai il giorno della settimana (0=Monday, 6=Sunday)
df_simple['giorno_settimana'] = df_simple['day'].dt.dayofweek

# Mappa numeri giorno della settimana a nomi
giorni_nome = {0: "Monday", 1: "Tuesday", 2: "Wednesday", 3: "Thursday",
               4: "Friday", 5: "Saturday", 6: "Sunday"}
df_simple['giorno_settimana_nome'] = df_simple['giorno_settimana'].map(giorni_nome)

# Pivot table: media valori 'telecamera' per giorno della settimana e mese
pivot = df_simple.pivot_table(
    index='giorno_settimana_nome',
    columns='mese',
    values='telecamera',
    aggfunc='mean'
)

# Ordinamento giorni della settimana
pivot = pivot.reindex(["Monday","Tuesday","Wednesday","Thursday","Friday","Saturday","Sunday"])

# Heatmap
plt.figure(figsize=(12,6))
sns.heatmap(pivot, annot=True, fmt=".1f", cmap="YlGnBu")  # float con 1 decimale
plt.xlabel("Month")
plt.ylabel("Day of the Week")
plt.title("Average Values by Day of the Week and Month")
plt.show()

# %%
import numpy as np
import pandas as pd

# Assicurati che 'day' sia datetime
df_simple["day"] = pd.to_datetime(df_simple["day"])

# Calcola giorno della settimana (0=Monday)
df_simple["giorno_settimana"] = df_simple["day"].dt.dayofweek

# Calcola media e deviazione standard complessive per giorno della settimana
stats_giorno = (
    df_simple.groupby("giorno_settimana")["telecamera"]
    .agg(["mean", "std"])
    .reset_index()
    .rename(columns={"mean": "media", "std": "devstd"})
)

# Unisci le statistiche al dataframe originale
df_simple = df_simple.merge(stats_giorno, on="giorno_settimana", how="left")

# Calcola numero di deviazioni standard sopra la media
anomalia_float = (df_simple["telecamera"] - df_simple["media"]) / df_simple["devstd"]

# Trasforma in 3 livelli interi
def livello_anomalia(x):
    if x <= 0.5:
        return 0  # nessuna anomalia
    elif 0.5 < x < 2:
        return 1  # piccola anomalia
    else:
        return 2  # grande anomalia

df_simple["anomalia"] = anomalia_float.apply(livello_anomalia)

# Rimuovi colonne temporanee
df_simple = df_simple.drop(columns=["media", "devstd"])

# Controlla il risultato
df_simple.head()
# Out:
#          day  telecamera  mese  giorno_settimana giorno_settimana_nome  \
# 0 2022-03-01       286.0     3                 1               Tuesday
# 1 2022-03-02       291.0     3                 2             Wednesday
# 2 2022-03-03       263.0     3                 3              Thursday
# 3 2022-03-04       292.0     3                 4                Friday
# 4 2022-03-05       763.0     3                 5              Saturday
#
#    anomalia
# 0         0
# 1         0
# 2         0
# 3         0
# 4         1

# %%
# Se stai usando df_simple (già con 'day', 'telecamera', 'anomalia')
df_subset = df_simple[['day', 'telecamera', 'anomalia']]
df_subset.to_csv('telecamera_dozza.csv', index=False)
print("CSV salvato correttamente con colonne: data, telecamera, anomalia")
# Out:
# CSV salvato correttamente con colonne: data, telecamera, anomalia

# %%
import matplotlib.pyplot as plt
import matplotlib.cm as cm
import matplotlib.colors as mcolors

fig, ax = plt.subplots(figsize=(15,6))

# Define palette for days of the week
days = ["Monday", "Tuesday", "Wednesday", "Thursday", "Friday", "Saturday", "Sunday"]
palette = cm.tab10  # 10 distinct colors

# Normalize anomaly level for point size
anomaly_norm = mcolors.Normalize(vmin=df_simple["anomalia"].min(), vmax=df_simple["anomalia"].max())

# Scatter plot
for i, day_name in enumerate(days):
    subset = df_simple[df_simple["day"].dt.dayofweek == i]  # calcola giorno della settimana direttamente
    ax.scatter(
        subset["day"],
        subset["telecamera"],  # colonna aggiornata
        c=[palette(i)]*len(subset),  # color by day of the week
        s=50 + 150 * anomaly_norm(subset["anomalia"]),  # size based on anomaly
        alpha=0.7,
        label=day_name
    )

ax.set_xlabel("Date")
ax.set_ylabel("People")
ax.set_title("Daily Entries - Color=Day, Size=Anomaly")
ax.tick_params(axis='x', rotation=45)
ax.grid(True)
ax.legend(title="Day of the Week")
plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt
import pandas as pd

# Assicurati che 'day' sia datetime
df_simple["day"] = pd.to_datetime(df_simple["day"])

# Seleziona solo l'anno 2025 e i mesi indicati
selected_months = [3, 5, 8, 9]  # marzo, maggio, agosto, settembre
filtered = df_simple[
    (df_simple["day"].dt.year == 2025) &
    (df_simple["day"].dt.month.isin(selected_months))
].copy()

# Rimuovi eventuali NaN
filtered = filtered.dropna(subset=["telecamera"])

plt.figure(figsize=(15,6))

# Linea principale
plt.plot(
    filtered["day"].values,
    filtered["telecamera"].values,
    color='blue',
    linewidth=1.5,
    label="Ingressi"
)

# Linee verticali sottili solo sulle domeniche
sundays = filtered[filtered["day"].dt.weekday == 6]["day"]
for sunday in sundays:
    plt.axvline(sunday, color='gray', linestyle='--', linewidth=0.5, alpha=0.5)

# Evidenzia anomalie con colori sulle linee
# Qui possiamo usare scatter per evidenziare i punti di anomalia sopra la linea
color_map = {1: "orange", 2: "red"}  # 1=piccola, 2=grande
for level, color in color_map.items():
    subset = filtered[filtered["anomalia"] == level]
    plt.scatter(
        subset["day"].values, subset["telecamera"].values,
        c=color, s=40, label=f"Anomalia livello {level}", zorder=5
    )

plt.title("Ingressi giornalieri - Mesi selezionati 2025")
plt.xlabel("Data")
plt.ylabel("Persone")
plt.xticks(rotation=45)
plt.grid(True)
plt.legend()
plt.tight_layout()
plt.show()

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

from sklearn.ensemble import GradientBoostingRegressor
from sklearn.model_selection import TimeSeriesSplit, RandomizedSearchCV
from sklearn.metrics import mean_squared_error, mean_absolute_error

# ======================================================
# 1️⃣ PREPARAZIONE DATI
# ======================================================

# Assicurati che 'giorno' sia datetime
df_simple["day"] = pd.to_datetime(df_simple["day"])

# Ordina temporalmente
daily_totals = df_simple.sort_values("day").reset_index(drop=True)

# Feature temporali
daily_totals["giorno_settimana"] = daily_totals["day"].dt.weekday
daily_totals["mese"] = daily_totals["day"].dt.month
daily_totals["giorno_mese"] = daily_totals["day"].dt.day


# Rimuove righe con NaN dovute ai lag
daily_totals = daily_totals.dropna().reset_index(drop=True)

# Feature e target
feature_cols = [
    "giorno_settimana",
    "mese",
    "anomalia",
]

X = daily_totals[feature_cols]
y = daily_totals["telecamera"]

# ======================================================
# 2️⃣ CROSS-VALIDATION TEMPORALE
# ======================================================

tscv = TimeSeriesSplit(n_splits=5)

# ======================================================
# 3️⃣ SPAZIO IPERPARAMETRI
# ======================================================

param_distributions = {
    "n_estimators": [100, 200, 300, 500],
    "learning_rate": [0.01, 0.05, 0.1, 0.2],
    "max_depth": [2, 3, 4, 5],
    "min_samples_split": [2, 5, 10],
    "min_samples_leaf": [1, 3, 5],
    "subsample": [0.6, 0.8, 1.0]
}

# ======================================================
# 4️⃣ RANDOMIZED SEARCH
# ======================================================

gbr = GradientBoostingRegressor(random_state=42)

random_search = RandomizedSearchCV(
    estimator=gbr,
    param_distributions=param_distributions,
    n_iter=40,
    cv=tscv,
    scoring="neg_root_mean_squared_error",
    n_jobs=-1,
    random_state=42,
    verbose=1
)

random_search.fit(X, y)

best_model = random_search.best_estimator_

print("\nMigliori iperparametri:")
print(random_search.best_params_)

# ======================================================
# 5️⃣ TRAIN / TEST SPLIT FINALE (ULTIMO 10%)
# ======================================================

split_idx = int(len(X) * 0.9)

X_train, X_test = X.iloc[:split_idx], X.iloc[split_idx:]
y_train, y_test = y.iloc[:split_idx], y.iloc[split_idx:]

best_model.fit(X_train, y_train)
y_pred = best_model.predict(X_test)

# ======================================================
# 6️⃣ METRICHE
# ======================================================

rmse = np.sqrt(mean_squared_error(y_test, y_pred))
mae = mean_absolute_error(y_test, y_pred)
mape = np.mean(np.abs((y_test - y_pred) / y_test)) * 100

print(f"\nRMSE: {rmse:.2f}")
print(f"MAE: {mae:.2f}")
print(f"MAPE: {mape:.2f}%")

# ======================================================
# 7️⃣ VISUALIZZAZIONE
# ======================================================

plt.figure(figsize=(12, 6))
plt.plot(y_test.values, label="Valore reale", marker="o")
plt.plot(y_pred, label="Predetto", marker="x")
plt.xlabel("Giorni test")
plt.ylabel("Entrate totali giornaliere")
plt.title(f"Predizione Entrate giornaliere - Telecamera {telecamera_scelta}")
plt.legend()
plt.grid(True)
plt.show()
# Out:
# Fitting 5 folds for each of 40 candidates, totalling 200 fits
#
# Migliori iperparametri:
# {'subsample': 1.0, 'n_estimators': 100, 'min_samples_split': 10, 'min_samples_leaf': 3, 'max_depth': 3, 'learning_rate': 0.05}
#
# RMSE: 93.41
# MAE: 67.71
# MAPE: 16.50%

# %%
import joblib

# Salva il modello in un file .pkl
filename = "pedestrians_model.pkl"
joblib.dump(best_model, filename)

print(f"Modello salvato in {filename}")
# Out:
# Modello salvato in pedestrians_model.pkl
